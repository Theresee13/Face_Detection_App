# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
model = YOLO("C:\\Users\\hp\\Yolo practical\\Yolo practical\\yolov8n-face.pt")

# %%
import cv2

def find_working_cameras(max_cameras=10):
    working_cameras = []
    for i in range(max_cameras):
        cap = cv2.VideoCapture(i)
        if cap.isOpened():
            ret, frame = cap.read()
            if ret:
                print(f"✅ Camera {i} is working.")
                working_cameras.append(i)
            cap.release()
        else:
            cap.release()
    return working_cameras

# تجربة:
working_cams = find_working_cameras()

print("\n📸 الكاميرات الفعّالة:", working_cams)
# Out:
# ✅ Camera 0 is working.
#
# 📸 الكاميرات الفعّالة: [0]

# %%
import cv2
import time

def find_working_cameras(max_cameras=10):
    working_cameras = []
    for i in range(max_cameras):
        cap = cv2.VideoCapture(i)
        if cap.isOpened():
            ret, frame = cap.read()
            if ret:
                print(f"✅ Camera {i} is working.")
                working_cameras.append(i)
            cap.release()
        else:
            cap.release()
    return working_cameras

def open_camera(camera_id=0):
    cap = cv2.VideoCapture(camera_id)
    if not cap.isOpened():
        print("❌ Error: Could not open camera.")
        return

    print("✅ Camera is opened. Starting detection...")
    time.sleep(1)  # ✨ اعطاء مهلة للكاميرا لتستقر

    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Error: Can't receive frame (stream end?). Retrying...")
            time.sleep(0.5)  # ✨ انتظر قليلا وحاول مجدداً
            continue

                # Apply the YOLO model to the frame
        results = model.predict(source=frame, save=False, verbose=False) 
    
        # Plot the results
        frame_with_boxes = results[0].plot()
    
        # Show the frame with the detection boxes
        cv2.imshow('YOLO Live Face Detection 🎯', frame_with_boxes)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# تجربة:
working_cams = find_working_cameras()

print("\n📸 الكاميرات الفعّالة:", working_cams)

if working_cams:
    open_camera(working_cams[0])
# Out:
# ✅ Camera 0 is working.
#
# 📸 الكاميرات الفعّالة: [0]
# ✅ Camera is opened. Starting detection...
